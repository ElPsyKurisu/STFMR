# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from vectormagnetcontrol import*

# %%
x,y = read_callibration_file("1to3_callibration.txt")
plt.scatter(x,y)

# %%
#assuming we pole high, i can make it simply find the first set of values between the values we want to interpolate
#since the order is in 10-> -10 then back to 10. for smaller stuff it may be more difficult
#i should talk to lucas though
